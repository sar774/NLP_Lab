# %% [markdown]
# # Text Representation

# %% [markdown]
# Text representation in NLP means converting text into a numerical form that a machine learning model can understand and process.

# %% [markdown]
# ## What is Embedding?
#
# Embeddings in NLP is a technique where individual words are represented as real-valued vectors and captures inter-word semantics.
#
#
# In this notebook, We going to intreduce 2 techniques for embedding. These techniques will be used for a machine learning models such as SVM, Random forest, ... ect.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1jd0u_sGppDKqBYbhtJfGxp14lnUWUTTw" width="900">

# %% [markdown]
# # 1- TF-IDF
#
# <img src="https://drive.google.com/uc?export=view&id=1saSt0mMgOQ2ybbTms1lu_ruhUcBWkKzL" width="500">

# %% [markdown]
# TF-IDF stands for term frequency-inverse document frequency. It is a measure that discounts common words. Used in the fields of information retrieval (IR) and machine learning, that can quantify the importance of words in a document amongst a collection of documents (also known as a corpus).

# %% [markdown]
# ### Components of TF-IDF
#
# 1. **TF (Term Frequency):**
#    Measures how frequently a term appears in a document.
#
#
# $$ \text{TF}(t, d) = \frac{\text{Number of times term } t \text{ appears in document } d}{\text{Total number of terms in document } d} $$
#
#
# 2. **IDF (Inverse Document Frequency):**
#    Measures how important a term is across all documents. Words that appear in many documents get lower scores.
#
# $$    \text{IDF}(t) = \log \left(\frac{\text{Number of all documents N}}{\text{Number of documents containing the term } t}\right) $$

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1JqPILC8TTh3yDQZCSuPNXwm6ER5YeJFh" width="900">

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
doc_1 = "Data is the oil of the digital economy"
doc_2 = "Data is a new oil"

data = [doc_1, doc_2]

# %%
tfidf = TfidfVectorizer()
result = tfidf.fit_transform(data) # returns sparce matrix

# %%
df = pd.DataFrame(result.toarray(), columns=tfidf.get_feature_names_out())
df
# Out:
#        data  digital  economy        is       new       of       oil      the
# 0  0.243777  0.34262  0.34262  0.243777  0.000000  0.34262  0.243777  0.68524
# 1  0.448321  0.00000  0.00000  0.448321  0.630099  0.00000  0.448321  0.00000

# %% [markdown]
# # Cosine similarity
#
# In NLP, Cosine similarity is a metric used to measure how similar the documents are.
#
#
# $$ \text{cosine similarity} = \frac{A \cdot B}{\|A\| \times \|B\|} $$
#
# Where:
# $ A \cdot B $  = dot product of vectors A and B
# $ \|A\| $ = magnitude (length) of vector A
# $ \|B\| $ =  magnitude (length) of vector B
#
# #### Intuition
#
# - If vectors point in the **same direction**, cosine similarity = **1** (maximum similarity).
# - If vectors are **orthogonal (90° apart)**, cosine similarity = **0** (no similarity).
#
# <img src="https://drive.google.com/uc?export=view&id=1b-o8CVfHBsjUGY_hXmxevU91gHidIuxO" width="900">

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Sample text data (replace with your own documents)

doc_1 = "Data is the oil of the digital economy"
doc_2 = "Data is a new oil"

data = [doc_1, doc_2]

# %%
tfidf_vectorizer = TfidfVectorizer() # Create a CountVectorizer instance
vector_matrix = tfidf_vectorizer.fit_transform(data) # Fit and transform the documents into numerical vectors

# %%
# Calculate the cosine similarity between the documents
cosine_similarity_matrix = cosine_similarity(vector_matrix)

df_cosine = pd.DataFrame(data=cosine_similarity_matrix, index=data, columns=data)

df_cosine
# Out:
#                                         Data is the oil of the digital economy  \
# Data is the oil of the digital economy                                1.000000
# Data is a new oil                                                     0.327871
#
#                                         Data is a new oil
# Data is the oil of the digital economy           0.327871
# Data is a new oil                                1.000000

# %% [markdown]
# # 2- What is Word2vec?

# %% [markdown]
# Word2Vec consists of models for generating word embedding. These models are two-layer neural networks having one input layer, one hidden layer, and one output layer.
#
# Word2Vec utilizes two architectures :
# 1. CBOW (Continuous Bag of Words)
# 2. **Skip Gram**
# <img src="https://drive.google.com/uc?export=view&id=1K38nEu_KhgtSJuG2RySwc6U5AAjVAgWZ" width="600">
#
#
# Run this command in terminal to install
# > pip install gensim

# %% [markdown]
# # Tasks

# %% [markdown]
# ### Task 1: Cosine Similarity
# Use the Cosine Similarity method to determine how similar the following sentences are.
#
# 'This is the first document.',
# 'This document is the second document.',
# 'And this is the third one.',
# 'Is this the first document?'

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sentences = [
    "This is the first document.",
    "This document is the second document.",
    "And this is the third one.",
    "Is this the first document?"
]

tfidf = TfidfVectorizer()

vectors = tfidf.fit_transform(sentences)

similarity = cosine_similarity(vectors)

df_similarity = pd.DataFrame(
    similarity,
    index=sentences,
    columns=sentences
)

print(df_similarity.round(3))
# Out:
#                                        This is the first document.  \
# This is the first document.                                  1.000
# This document is the second document.                        0.647
# And this is the third one.                                   0.308
# Is this the first document?                                  1.000
#
#                                        This document is the second document.  \
# This is the first document.                                            0.647
# This document is the second document.                                  1.000
# And this is the third one.                                             0.225
# Is this the first document?                                            0.647
#
#                                        And this is the third one.  \
# This is the first document.                                 0.308
# This document is the second document.                       0.225
# And this is the third one.                                  1.000
# Is this the first document?                                 0.308
#
#                                        Is this the first document?
# This is the first document.                                  1.000
# This document is the second document.                        0.647
# And this is the third one.                                   0.308
# Is this the first document?                                  1.000

# %% [markdown]
# ### Task 2: TF-IDF
# Use tf-idf method on the sentences below to determine the important words.
#
# 'data science is one of the most important fields of science',
# 'this is one of the best data science courses',
# 'data scientists analyze data'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

sentences = [
    "data science is one of the most important fields of science",
    "this is one of the best data science courses",
    "data scientists analyze data"
]

vectorizer = TfidfVectorizer(stop_words="english")

tfidf_matrix = vectorizer.fit_transform(sentences)

words = vectorizer.get_feature_names_out()

for i, row in enumerate(tfidf_matrix.toarray()):
    top_indices = row.argsort()[::-1][:3]

    print(f"Sentence {i+1}:")
    for index in top_indices:
        print(words[index], round(row[index], 3))
    print()
# Out:
# Sentence 1:
# science 0.704
# important 0.463
# fields 0.463
#
# Sentence 2:
# best 0.584
# courses 0.584
# science 0.445
#
# Sentence 3:
# data 0.641
# scientists 0.543
# analyze 0.543

# %% [markdown]
# ## Word2vec

# %% [markdown]
# ### Task 3:
#
# Download the Simpsons dataset **(simpsons_script_lines.csv)** and apply the preprocessing procedure.
# Use the **'spoken_words'** column.
# ```
# def clean_text(text):
#     text = text.lower()
#     text = re.sub(r"[0-9]", '', text)
#     text = re.sub(r"[)(,”“.’$-]", '', text)
#     return text
# ```
# Create a skip gram Word2Vec model as below.
# ```
# Skip_gram_model = gensim.models.Word2Vec(tokens, min_count = 1, vector_size = 100, window = 5, sg = 1)

# %%
import pandas as pd

df = pd.read_csv("simpsons_script_lines.csv")

print("Dataset shape:", df.shape)
print("Columns:", df.columns.tolist())

df[["spoken_words"]].head()
# Out:
# Dataset shape: (158314, 2)
# Columns: ['raw_character_text', 'spoken_words']
#                                         spoken_words
# 0  No, actually, it was a little of both. Sometim...
# 1                             Where's Mr. Bergstrom?
# 2  I don't know. Although I'd sure like to talk t...
# 3                         That life is worth living.
# 4  The polls will be open from now until the end ...

# %%
import re

# Remove missing values
df = df.dropna(subset=["spoken_words"]).copy()

# Preprocessing function from the lab
def clean_text(text):
    text = text.lower()
    text = re.sub(r"[0-9]", "", text)
    text = re.sub(r"[)(,”“.’$-]", "", text)
    return text

# Clean the spoken_words column
df["cleaned_text"] = df["spoken_words"].apply(clean_text)

# Tokenization
tokens = [
    line.split()
    for line in df["cleaned_text"]
    if line.strip()
]

print("Number of tokenized lines:", len(tokens))
print("First 3 tokenized lines:")
print(tokens[:3])
# Out:
# Number of tokenized lines: 131839
# First 3 tokenized lines:
# [['no', 'actually', 'it', 'was', 'a', 'little', 'of', 'both', 'sometimes', 'when', 'a', 'disease', 'is', 'in', 'all', 'the', 'magazines', 'and', 'all', 'the', 'news', 'shows', "it's", 'only', 'natural', 'that', 'you', 'think', 'you', 'have', 'it'], ["where's", 'mr', 'bergstrom?'], ['i', "don't", 'know', 'although', "i'd", 'sure', 'like', 'to', 'talk', 'to', 'him', 'he', "didn't", 'touch', 'my', 'lesson', 'plan', 'what', 'did', 'he', 'teach', 'you?']]

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\sara salah\anaconda3\lib\site-packages (4.4.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.18.5 in c:\users\sara salah\anaconda3\lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\sara salah\anaconda3\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\sara salah\anaconda3\lib\site-packages (from gensim) (8.0.1)
# Requirement already satisfied: wrapt in c:\users\sara salah\anaconda3\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)

# %%
import gensim

Skip_gram_model = gensim.models.Word2Vec(
    tokens,
    min_count=1,
    vector_size=100,
    window=5,
    sg=1
)

print("Model trained successfully!")
print("Vocabulary size:", len(Skip_gram_model.wv))
print("Vector size:", Skip_gram_model.vector_size)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %% [markdown]
# **Execution note:** This saved Word2Vec training run emitted internal `gensim` `Exception ignored` messages. They have been retained rather than hidden. The vector finiteness check and similarity queries below ran successfully, but the cause of those messages has not been resolved.

# %%
import numpy as np

print("All vectors are finite:",
      np.isfinite(Skip_gram_model.wv.vectors).all())

print("Homer test:",
      Skip_gram_model.wv.most_similar("homer", topn=1))
# Out:
# All vectors are finite: True
# Homer test: [('abe', 0.8784244060516357)]

# %% [markdown]
# ### Task 4
#
# Use: wv.most_similar() method to :
#
# 1.	Find the words similar to “homer”.
#
# 2.	Find the words similar to “marge”.
#
# 3. Find the words similar to “bart”

# %%
words = ["homer", "marge", "bart"]

for word in words:
    print(f"\nWords similar to {word}:")
    print(Skip_gram_model.wv.most_similar(word))
# Out:
# Words similar to homer:
# [('marge', 0.8700397610664368), ('abe', 0.8608444333076477), ('bart', 0.8508046269416809), ('barney', 0.8418304324150085), ('bartholomew', 0.8356034755706787), ('eliza', 0.822598397731781), ('apu', 0.8214086890220642), ('grampa', 0.8207155466079712), ('monty', 0.8178840279579163), ('son', 0.809998631477356)]
#
# Words similar to marge:
# [('abe', 0.8799300193786621), ('homer', 0.8700397610664368), ('honey', 0.8662078380584717), ('sweetie', 0.8641972541809082), ('becky', 0.8456441760063171), ('sweetheart', 0.8401843905448914), ('eliza', 0.8395455479621887), ('lisa', 0.8387184739112854), ('homie', 0.8311001062393188), ('apu', 0.8292081952095032)]
#
# Words similar to bart:
# [('lisa', 0.8823534846305847), ('milhouse', 0.8645124435424805), ('homer', 0.8508046269416809), ('abe', 0.8494024872779846), ('maggie', 0.8476182222366333), ('grampa', 0.8449041247367859), ('eliza', 0.8423863053321838), ('apu', 0.840747058391571), ('jessica', 0.833714485168457), ('sweetie', 0.8291793465614319)]

# %% [markdown]
# ### Task 5
#
# Use the wv.doesnt_match() method to :
#
# 1.	Find which of 'jimbo', 'milhouse’, and 'kearney’ does not belong to the list.
#
# 3.	Find the odd one among "nelson", "bart", and "milhouse".
#
# 4.	Find the odd one among ‘homer', 'patty', and ‘selma'.
#
# *Hint: You need to pass the strings as List*

# %%
groups = [
    ["jimbo", "milhouse", "kearney"],
    ["nelson", "bart", "milhouse"],
    ["homer", "patty", "selma"]
]

for group in groups:
    odd_word = Skip_gram_model.wv.doesnt_match(group)
    print(f"{group} -> Odd word: {odd_word}")
# Out:
# ['jimbo', 'milhouse', 'kearney'] -> Odd word: milhouse
# ['nelson', 'bart', 'milhouse'] -> Odd word: bart
# ['homer', 'patty', 'selma'] -> Odd word: homer
